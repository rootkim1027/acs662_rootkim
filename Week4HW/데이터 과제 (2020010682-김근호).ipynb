# %%
import numpy as np
import matplotlib.gridspec as gridspec

# %%
particle = np.loadtxt('coord.out', skiprows=1 , dtype=float)
print(particle)
# Out:
# [[ 0.0000e+00  1.0000e+00  8.2634e-08 ...  3.0776e-02  1.9325e-05
#    3.1892e-02]
#  [ 0.0000e+00  1.0000e+00 -1.1558e+01 ...  8.7582e+00 -1.6615e-01
#    8.0275e+00]
#  [ 0.0000e+00  1.0000e+00  8.0130e-01 ... -2.9157e+00 -3.8427e-02
#    1.3129e+01]
#  ...
#  [ 0.0000e+00  1.0000e+00 -1.1617e+01 ...  7.7016e+00 -6.1860e-02
#   -4.8626e+00]
#  [ 0.0000e+00  1.0000e+00  1.6378e+01 ...  1.9709e+01 -1.7698e-02
#   -5.3058e+00]
#  [ 0.0000e+00  1.0000e+00  5.3429e+00 ... -3.6098e+00 -6.4271e-02
#    2.0248e+01]]

# %%
x= particle[:,4]
y = particle [:,5]

# %%
print(x)
print(xp)
# Out:
# [ 0.00085039 -0.046729   -0.010348   ... -0.072774    0.047119
#   0.20461   ]
# [ 0.030776  8.7582   -2.9157   ...  7.7016   19.709    -3.6098  ]

# %%
from matplotlib import pyplot as plt
def scatter_hist(x, y, ax, ax_histx, ax_histy):
    
    ax_histx.tick_params(axis='x',labelbottom=False)
    ax_histy.tick_params(axis='y', labelleft=False)
        # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.05
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins/100)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
fig = plt.figure(figsize=(10,10))

grid = plt.GridSpec(2, 2,  width_ratios=(7, 2), height_ratios=(2, 7),
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)

ax = fig.add_subplot(grid[1,0])

ax_histx = fig.add_subplot(grid[0,0],sharex=ax)
ax_histy = fig.add_subplot(grid[1,1],sharey=ax)

scatter_hist(x, xp, ax, ax_histx, ax_histy)

plt.show()

# %%
from matplotlib import pyplot as plt
def scatter_histp(x, y, ax, ax_histx, ax_histy):
    
    ax_histx.tick_params(axis='x',labelbottom=False)
    ax_histy.tick_params(axis='y', labelleft=False)
        # the scatter plot:
    ax.scatter(x, y)

    # now determine nice limits by hand:
    binwidth = 0.05
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')

# %%
alx=0.399
bex=0.0109

lx=x/((bex)**(0.5))

lxp=(alx*x+bex*xp)/((bex)**(0.5))

# %%
fig = plt.figure(figsize=(10,10))

grid = plt.GridSpec(2, 2,  width_ratios=(7, 2), height_ratios=(2, 7),
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)

ax = fig.add_subplot(grid[1,0])

ax_histx = fig.add_subplot(grid[0,0],sharex=ax)
ax_histy = fig.add_subplot(grid[1,1],sharey=ax)
                 
scatter_histp(lx, lxp, ax, ax_histx, ax_histy)

plt.show()
